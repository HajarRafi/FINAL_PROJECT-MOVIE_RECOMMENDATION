# %%
#import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data
data = pd.read_csv('data/movies_metadata_1.csv').set_index('id')
data.head()
# Out:
#                              title  popularity    budget      revenue  \
# id
# 862                      Toy Story   21.946943  30000000  373554033.0
# 8844                       Jumanji   17.015539  65000000  262797249.0
# 15602             Grumpier Old Men   11.712900         0          0.0
# 31357            Waiting to Exhale    3.859495  16000000   81452156.0
# 11862  Father of the Bride Part II    8.387519         0   76578911.0
#
#        runtime  vote_average  vote_count  \
# id
# 862       81.0           7.7      5415.0
# 8844     104.0           6.9      2413.0
# 15602    101.0           6.5        92.0
# 31357    127.0           6.1        34.0
# 11862    106.0           5.7       173.0
#
#                                                 overview
# id
# 862    Led by Woody, Andy's toys live happily in his ...
# 8844   When siblings Judy and Peter discover an encha...
# 15602  A family wedding reignites the ancient feud be...
# ...

# %%
#check statistic of numerical columns
data.describe().T
# Out:
#                 count          mean           std  min       25%        50%  \
# popularity    45002.0  2.939094e+00  6.024023e+00  0.0   0.39093   1.135661
# budget        45002.0  4.266310e+06  1.750789e+07  0.0   0.00000   0.000000
# revenue       45002.0  1.132191e+07  6.464887e+07  0.0   0.00000   0.000000
# runtime       45002.0  9.374341e+01  3.889375e+01  0.0  85.00000  95.000000
# vote_average  45002.0  5.623728e+00  1.916004e+00  0.0   5.00000   6.000000
# vote_count    45002.0  1.109098e+02  4.936925e+02  0.0   3.00000  10.000000
#
#                      75%           max
# popularity      3.730199  5.474883e+02
# budget          0.000000  3.800000e+08
# revenue         0.000000  2.787965e+09
# runtime       107.000000  1.256000e+03
# vote_average    6.800000  1.000000e+01
# vote_count     35.000000  1.407500e+04

# %%
#plot correlation matrix
correlations_matrix = data.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
#select columns with relatively high correlation
correlated_columns = data[['vote_count', 'popularity', 'budget', 'revenue']]

# %%
correlations_matrix = correlated_columns.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
#regression plot of the columns
sns.regplot(x="revenue", y="vote_count", data=data).set(title="VOTE COUNT VS REVENUE (corr = 0.81)")
# Out:
# [Text(0.5, 1.0, 'VOTE COUNT VS REVENUE (corr = 0.81)')]

# %%
sns.regplot(x="budget", y="vote_count", data=data).set(title="VOTE COUNT VS BUDGET (corr = 0.68)")
# Out:
# [Text(0.5, 1.0, 'VOTE COUNT VS BUDGET (corr = 0.68)')]

# %%
sns.regplot(x="popularity", y="vote_count", data=data).set(title="VOTE COUNT VS POPULARITY (corr = 0.56)")
# Out:
# [Text(0.5, 1.0, 'VOTE COUNT VS POPULARITY (corr = 0.56)')]

# %%
sns.regplot(x="revenue", y="budget", data=data).set(title="REVENUE VS BUDGET (corr = 0.77)")
# Out:
# [Text(0.5, 1.0, 'REVENUE VS BUDGET (corr = 0.77)')]

# %%
sns.regplot(x="revenue", y="popularity", data=data).set(title="REVENUE VS POPULARITY (corr = 0.51)")
# Out:
# [Text(0.5, 1.0, 'REVENUE VS POPULARITY (corr = 0.51)')]

# %%
sns.regplot(x="budget", y="popularity", data=data).set(title="BUDGET VS POPULARITY (corr = 0.45)")
# Out:
# [Text(0.5, 1.0, 'BUDGET VS POPULARITY (corr = 0.45)')]
